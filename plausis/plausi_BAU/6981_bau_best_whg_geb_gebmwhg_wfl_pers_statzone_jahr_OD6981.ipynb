# %% [markdown]
# **Importiere die notwendigen Packages**

# %%
# Empfehlung für Colab: Installiere alles was Du brauchst
# %pip install pandas pivottablejs numpy altair matplotlib geopandas folium

# %%
import pandas as pd
import pivottablejs
from pivottablejs import pivot_ui
import numpy as np
import altair as alt
import matplotlib.pyplot as plt
from datetime import datetime
import geopandas as gpd
import folium
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-1-5ac4ae77711f> in <module>
#       6 import matplotlib.pyplot as plt
#       7 from datetime import datetime
# ----> 8 import geopandas as gpd
#       9 import folium
#      10
#
# ModuleNotFoundError: No module named 'geopandas'

# %% [markdown]
# Definiere Settings. Hier das Zahlenformat von Float-Werten (z.B. *'{:,.2f}'.format* mit Komma als Tausenderzeichen),

# %%
pd.options.display.float_format = '{:.0f}'.format
pd.set_option('display.width', 100)
pd.set_option('display.max_columns', 15)

# %% [markdown]
# Importiere einen Datensatz von der **DWH_INT** Dropzone.
#
# - Beachte dabei die Notation des Pfades...
# - Definiere mal aktuell noch keine weiteren Parameter beim Import

# %% [markdown]
# **Dataset auf INTEG Datenkatalog**: https://data.integ.stadt-zuerich.ch/dataset/int_dwh_bau_best_whg_geb_gebmwhg_wfl_pers_statzone_jahr_od6981
#
# (int_dwh)

# %%
# Filepath
#INT
fp = r"//szh.loc/ssz/applikationen/OGD_Dropzone/INT_DWH/bau_best_whg_geb_gebmwhg_wfl_pers_statzone_jahr_OD6981/BAU698OD6981.csv"
#bau_best_whg_geb_gebmwhg_wfl_pers_statzone_jahr_OD6981

#PROD
#fp = r"//szh.loc/ssz/applikationen/OGD_Dropzone/DWH/bau_best_whg_geb_gebmwhg_wfl_pers_statzone_jahr_OD6981/BAU698OD6981.csv"

# bau_best_whg_wfl_pers_ea_quartier_jahr_od6982



# Read the data
data2betested = pd.read_csv(
    fp, 
    sep=',',
   #usecols=[0,1,2,3,4,6],
   #names=['stationid','year','month','avgtemp','latitude','longitude','elevation','station','countryid','country'],
   #skiprows=1,
   # parse_dates=[0],
    parse_dates=True,
    #date_parser=lambda x: pd.to_datetime(x, format="%Y"), 
    #index_col="date_time",
    low_memory=False    
    )

# %% [markdown]
# In der Folge ein paar erste Tests:

# %%
type(data2betested)
# Out:
# pandas.core.frame.DataFrame

# %% [markdown]
#  - 1) Zeige eine kurze Vorschau der importierten Daten
#  - 2) Weise die Datentypen aus
#  - 3) Zeige die Shape (Umfang) des Datensatzes an

# %%
data2betested.head(3000)
# Out:
#       StichtagDatJahr  StatZoneSort       StatZoneLang  QuarSort    QuarLang  KreisSort KreisLang  \
# 0                2008             1   Zähringerstrasse         1     Rathaus          1   Kreis 1
# 1                2008             1   Zähringerstrasse         1     Rathaus          1   Kreis 1
# 2                2008             2           Prediger         1     Rathaus          1   Kreis 1
# 3                2008             2           Prediger         1     Rathaus          1   Kreis 1
# 4                2008             3       Grossmünster         1     Rathaus          1   Kreis 1
# ...               ...           ...                ...       ...         ...        ...       ...
# 2995             2014           214  Hirzenbachstrasse        34  Hirzenbach         12  Kreis 12
# 2996             2014           214  Hirzenbachstrasse        34  Hirzenbach         12  Kreis 12
# 2997             2014           215          Mattenhof        34  Hirzenbach         12  Kreis 12
# 2998             2014           215          Mattenhof        34  Hirzenbach         12  Kreis 12
# 2999             2014           216    Probsteistrasse        34  Hirzenbach         12  Kreis 12
#
#       EigentumCd                   EigentumLang  AnzGeb  AnzGebMitWhg  AnzWhg  Wohnungsfl  \
# 0              1  staedtisch/genossenschaftlich      16             9      33        2508
# 1              2                         andere     102            74     401       21778
# 2              1  staedtisch/genossenschaftlich      81            61     266       17863
# 3              2                         andere     132            94     433       27578
# 4              1  staedtisch/genossenschaftlich      55            35     143       10246
# ...          ...                            ...     ...           ...     ...         ...
# 2995           1  staedtisch/genossenschaftlich     121            68     587       38395
# 2996           2                         andere     141            93    1160       83000
# 2997           1  staedtisch/genossenschaftlich     189           127     906       57454
# 2998           2                         andere     184           154    1230       80899
# 2999           1  staedtisch/genossenschaftlich     290           205     393       31670
#
#       PersInGeb
# 0            52
# 1           479
# 2           435
# 3           566
# 4           258
# ...         ...
# 2995       1282
# 2996       2425
# 2997       1769
# 2998       2597
# 2999       1000
#
# [3000 rows x 14 columns]

# %%
data2betested.dtypes
# Out:
# StichtagDatJahr      int64
# StatZoneSort         int64
# StatZoneLang        object
# QuarSort             int64
# QuarLang            object
# KreisSort            int64
# KreisLang           object
# EigentumCd           int64
# EigentumLang        object
# AnzGeb               int64
# AnzGebMitWhg         int64
# AnzWhg               int64
# Wohnungsfl           int64
# PersInGeb          float64
# dtype: object

# %%
data2betested.shape
# Out:
# (5570, 14)

# %% [markdown]
# Beschreibe einzelne Attribute

# %%
data2betested.describe()
# Out:
#        StichtagDatJahr  StatZoneSort  StatZoneCd  QuarSort  QuarCd  KreisSort  KreisCd  \
# count             5570          5570        5570      5570    5570       5570     5570
# mean              2014           109        6891        19      69          7        7
# std                  4            62        3451         9      35          3        3
# min               2008             1        1101         1      11          1        1
# 25%               2011            55        3406        10      34          3        3
# 50%               2014           109        7202        19      72          7        7
# 75%               2017           163       10102        27     101         10       10
# max               2020           216       12304        34     123         12       12
#
#        EigentumCd  AnzGeb  AnzGebMitWhg  AnzWhg  Wohnungsfl  PersInGeb
# count        5570    5570          5570    5570        5570       5424
# mean            2     127            86     506       39164        973
# std             1     108            81     471       36399        842
# min             1       1             0       0           0          0
# 25%             1      38            14     102        8202        254
# 50%             2      95            62     395       30153        795
# 75%             2     195           138     768       60194       1493
# max             2     588           488    2447      200388       4785

# %% [markdown]
# Wie viele Nullwerte gibt es im Datensatz?

# %%
data2betested.isnull().sum()
# Out:
# StichtagDatJahr      0
# StatZoneSort         0
# StatZoneCd           0
# StatZoneLang         0
# QuarSort             0
# QuarCd               0
# QuarLang             0
# KreisSort            0
# KreisCd              0
# KreisLang            0
# EigentumCd           0
# EigentumLang         0
# AnzGeb               0
# AnzGebMitWhg         0
# AnzWhg               0
# Wohnungsfl           0
# PersInGeb          146
# dtype: int64

# %% [markdown]
# Wandle die Spalte Jahr von Int zu **Datetime** um. Dies wird in den meisten Grafiken so benötigt.

# %%
#data2betested['StichtagDatJahr']=pd.to_datetime(data2betested['StichtagDatJahr'], format='%Y')
data2betested['StichtagDatJahr']=pd.to_datetime(data2betested['StichtagDatJahr'], format='%Y')
#TO DO --> setze das Datum auf den 31.12. der Jahres.
#test=data2betested[['StichtagDatJahr']].date().replace(month=12, day=31)

data2betested
# Out:
#      StichtagDatJahr  StatZoneSort  StatZoneCd       StatZoneLang  QuarSort  QuarCd    QuarLang  \
# 0         2008-01-01             1        1101   Zähringerstrasse         1      11     Rathaus
# 1         2008-01-01             1        1101   Zähringerstrasse         1      11     Rathaus
# 2         2008-01-01             2        1102           Prediger         1      11     Rathaus
# 3         2008-01-01             2        1102           Prediger         1      11     Rathaus
# 4         2008-01-01             3        1103       Grossmünster         1      11     Rathaus
# ...              ...           ...         ...                ...       ...     ...         ...
# 5565      2020-01-01           214       12302  Hirzenbachstrasse        34     123  Hirzenbach
# 5566      2020-01-01           215       12303          Mattenhof        34     123  Hirzenbach
# 5567      2020-01-01           215       12303          Mattenhof        34     123  Hirzenbach
# 5568      2020-01-01           216       12304    Probsteistrasse        34     123  Hirzenbach
# 5569      2020-01-01           216       12304    Probsteistrasse        34     123  Hirzenbach
#
#       ...  EigentumCd                   EigentumLang AnzGeb  AnzGebMitWhg AnzWhg  Wohnungsfl  \
# 0     ...           1  staedtisch/genossenschaftlich     16             9     33        2508
# 1     ...           2                         andere    102            74    401       21778
# 2     ...           1  staedtisch/genossenschaftlich     81            61    266       17863
# 3     ...           2                         andere    132            94    433       27578
# 4     ...           1  staedtisch/genossenschaftlich     55            35    143       10246
# ...   ...         ...                            ...    ...           ...    ...         ...
# 5565  ...           2                         andere    145            94   1191       85634
# 5566  ...           1  staedtisch/genossenschaftlich    230           166   1252       91912
# 5567  ...           2                         andere    199           169   1392       95603
# 5568  ...           1  staedtisch/genossenschaftlich    296           203    391       31393
# 5569  ...           2                         andere    211           144    458       39617
#
#       PersInGeb
# 0            52
# 1           479
# 2           435
# 3           566
# 4           258
# ...         ...
# 5565       2431
# 5566       2633
# 5567       2860
# 5568        969
# 5569        871
#
# [5570 rows x 17 columns]

# %% [markdown]
# Bereite die Daten für die Grafik unten vor

# %%
Jahre = data2betested.groupby("StichtagDatJahr")
len(Jahre)
# Out:
# 13

# %%
for key, group in Jahre:
    print(key, len(group))
# Out:
# 2008-01-01 00:00:00 430
# 2009-01-01 00:00:00 430
# 2010-01-01 00:00:00 429
# 2011-01-01 00:00:00 428
# 2012-01-01 00:00:00 428
# 2013-01-01 00:00:00 428
# 2014-01-01 00:00:00 428
# 2015-01-01 00:00:00 428
# 2016-01-01 00:00:00 428
# 2017-01-01 00:00:00 428
# 2018-01-01 00:00:00 429
# 2019-01-01 00:00:00 428
# 2020-01-01 00:00:00 428

# %%
myJahr = "2020-01-01"
aktuellesJahr=Jahre.get_group(myJahr)   
aktuellesJahr.head(3)
# Out:
#      StichtagDatJahr  StatZoneSort  StatZoneCd      StatZoneLang  QuarSort  QuarCd QuarLang  ...  \
# 5142      2020-01-01             1        1101  Zähringerstrasse         1      11  Rathaus  ...
# 5143      2020-01-01             1        1101  Zähringerstrasse         1      11  Rathaus  ...
# 5144      2020-01-01             2        1102          Prediger         1      11  Rathaus  ...
#
#       EigentumCd                   EigentumLang AnzGeb  AnzGebMitWhg AnzWhg  Wohnungsfl  PersInGeb
# 5142           1  staedtisch/genossenschaftlich     16             9     33        2156         54
# 5143           2                         andere    104            77    396       23042        544
# 5144           1  staedtisch/genossenschaftlich     84            60    270       17774        453
#
# [3 rows x 17 columns]

# %% [markdown]
# **Selektionen und Aggregationen**
#
# Check this [Doku](https://www.shanelynn.ie/summarising-aggregation-and-grouping-data-in-python-pandas/)

# %%
#test = data2betested.groupby(['StichtagDatJahr', 'AlterV20Kurz'])[['AnzBestWir']].agg()

# produces Pandas Series
    #data2betested.groupby(['StichtagDatJahr', 'KonOGDSort'])['AnzBestWir'].sum()
# Produces Pandas DataFrame
    #data2betested.groupby(['StichtagDatJahr', 'KonOGDSort'])[['AnzBestWir']].sum()
    
test = data2betested.groupby(
    ['StichtagDatJahr']
#   ['Jahr','QuarSort', 'QuarLang']
).agg(
    {
         'AnzWhg':(sum),     # Sum --> (sum)
        'AnzGeb': 'sum',
         'AnzGebMitWhg': 'sum',   
         'Wohnungsfl': 'sum',  # get the first date per group
        'PersInGeb':'sum'
    }
)
test.head(100)
# Out:
#                  AnzWhg  AnzGeb  AnzGebMitWhg  Wohnungsfl  PersInGeb
# StichtagDatJahr
# 2008-01-01       206788   54067         36848    15653907     379312
# 2009-01-01       207581   53898         36723    15775493     381175
# 2010-01-01       208089   53912         36633    15869483     384508
# 2011-01-01       209754   54085         36645    16109896     389364
# 2012-01-01       211971   54152         36693    16331043     393717
# 2013-01-01       214472   54223         36773    16572924     398321
# 2014-01-01       215477   54155         36601    16719697     404112
# 2015-01-01       218057   54291         36640    17002472     410328
# 2016-01-01       219950   54158         36484    17196232     415181
# 2017-01-01       222249   54187         36543    17414000     422727
# 2018-01-01       225294   54455         36653    17664882     428149
# 2019-01-01       227136   54564         36703    17838273     433532
# 2020-01-01       228817   54573         36700    17992578     434523

# %% [markdown]
# **Einfache Visualisierungen zur Plausi**

# %% [markdown]
# Exploriere die Daten mit Pivottable.JS

# %%
from pivottablejs import pivot_ui

pivot_ui(data2betested)
# Out:
#         <iframe
#             width="100%"
#             height="500"
#             src="pivottablejs.html"
#             frameborder="0"
#             allowfullscreen
#         ></iframe>

# %% [markdown]
# Liniendiagramm
# [Link zur Doku](https://altair-viz.github.io/gallery/multiline_highlight.html)

# %%
mySelection = aktuellesJahr.groupby(['StichtagDatJahr', 'KreisLang'])['AnzWhg'].sum()
mySelection
# Out:
# StichtagDatJahr  KreisLang
# 2020-01-01       Kreis 1       3880
#                  Kreis 10     21387
#                  Kreis 11     37823
#                  Kreis 12     15737
#                  Kreis 2      17995
#                  Kreis 3      27337
#                  Kreis 4      16788
#                  Kreis 5       8511
#                  Kreis 6      18509
#                  Kreis 7      20556
#                  Kreis 8      10441
#                  Kreis 9      29853
# Name: AnzWhg, dtype: int64

# %%
mySelection = aktuellesJahr[["StichtagDatJahr","QuarLang","AnzWhg", 'AnzGeb', "Wohnungsfl", "PersInGeb"]]
mySelection
# Out:
#      StichtagDatJahr    QuarLang  AnzWhg  AnzGeb  Wohnungsfl  PersInGeb
# 5142      2020-01-01     Rathaus      33      16        2156         54
# 5143      2020-01-01     Rathaus     396     104       23042        544
# 5144      2020-01-01     Rathaus     270      84       17774        453
# 5145      2020-01-01     Rathaus     414     127       27079        572
# 5146      2020-01-01     Rathaus     149      56       10223        256
# ...              ...         ...     ...     ...         ...        ...
# 5565      2020-01-01  Hirzenbach    1191     145       85634       2431
# 5566      2020-01-01  Hirzenbach    1252     230       91912       2633
# 5567      2020-01-01  Hirzenbach    1392     199       95603       2860
# 5568      2020-01-01  Hirzenbach     391     296       31393        969
# 5569      2020-01-01  Hirzenbach     458     211       39617        871
#
# [428 rows x 6 columns]

# %%
agg_mySelection = mySelection.groupby(
   ['StichtagDatJahr', 'QuarLang']
).agg(
    {
         'AnzWhg':(sum,min, max),     # Sum --> (sum)
         #'Wohnungsfl': (sum, min, max),
        'Wohnungsfl': ('mean'),
        'AnzGeb': (sum, min, max),
        'PersInGeb':('sum')
    }
)
agg_mySelection
# Out:
#                                      AnzWhg            Wohnungsfl AnzGeb          PersInGeb
#                                         sum  min   max       mean    sum min  max       sum
# StichtagDatJahr QuarLang
# 2020-01-01      Affoltern             12061  244  2068      71258   2840  86  491     26584
#                 Albisrieden           11794   85  1757      51452   2469  13  276     22294
#                 Alt-Wiedikon          10294   12  2178      62061   1667  11  333     17763
#                 Altstetten            18059    4  1387      41657   3657   9  315     34096
#                 City                    392    1   213       4649    421   7  128       829
#                 Enge                   5391    0  1513      34666   1495   2  430      9655
#                 Escher Wyss            3261    4  1401      40203    597  16  226      6198
#                 Fluntern               4362    0  1044      39405   1898   3  526      8685
#                 Friesenberg            4529  101   810      30244   1890  43  363     11070
#                 Gewerbeschule          5250   31  1596      30592    869  16  213      9424
#                 Hard                   7062  221  1212      46560    935  33  193     12554
#                 Hirslanden             4127   33  1684      58872   1241  19  377      7396
#                 Hirzenbach             6211  148  1392      56232   1403  24  296     12963
#                 Hochschulen             329    4   173       4708    293  17  102       675
#                 Hottingen              6126    9  1492      41370   2174   3  465     11304
#                 Höngg                 12214    0  1726      52571   3375   3  445     24439
#                 Langstrasse            7303    4  1631      40487   1143   8  253     11893
#                 Leimbach               2653  232   625      37919    948  64  220      6111
#                 Lindenhof               842    0   416      10458    439   8  197      1010
#                 Mühlebach              3926   11  1426      38810    865   6  302      6414
#                 Oberstrass             5710    0  1328      35828   1869   6  350     10824
#                 Oerlikon              12526    0  2447      47486   2741   1  457     23548
#                 Rathaus                2317   33   549      19704    785  16  182      3317
#                 Saatlen                3568  240  1224      50822   1349  62  558      8799
#                 Schwamendingen-Mitte   5958  188  1031      41464   1254  49  209     11083
#                 Seebach               13236   32  1859      56297   2849  15  344     26055
#                 Seefeld                3639    0  1449      40069    747   4  250      5480
#                 Sihlfeld              12514   19  1859      53192   1609  13  239     21916
#                 Unterstrass           12799   11  1312      37943   2804  16  239     24407
#                 Weinegg                2876    0  1017      31468   1126   8  457      5562
#                 Werd                   2423   14   943      29050    411   2  161      4570
#                 Wipkingen              9173   60  1543      46843   1828  37  247     16605
#                 Witikon                5941    1  1672      40401   1996   8  446     11244
#                 Wollishofen            9951    0  1607      35761   2586   5  330     19756

# %%
# df_statzonen = df_statzonen[(df_statzonen.knr>0) & (df_statzonen.qname!="Hirslanden")]
#aktuellesJahr[[aktuellesJahr.KreisSort =7]])
highlight = alt.selection(type='single', on='mouseover',
                          fields=['EigGruLang'], nearest=True)
#x='date:StichtagDatJahr',
base = alt.Chart(mySelection).encode(
    x='StichtagDatJahr',
    y='AnzWhg',
    color='EigGruLang'
)

points = base.mark_circle().encode(
    opacity=alt.value(0)
).add_selection(
    highlight
).properties(
    width=700 , height=300
)
lines = base.mark_line().encode(
    size=alt.condition(~highlight, alt.value(1.5), alt.value(4))
).interactive()

points + lines
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# C:\ProgramData\Anaconda3\lib\site-packages\altair\vegalite\v4\api.py in to_dict(self, *args, **kwargs)
#     371
#     372         try:
# --> 373             dct = super(TopLevelMixin, copy).to_dict(*args, **kwargs)
#     374         except jsonschema.ValidationError:
#     375             dct = None
#
# C:\ProgramData\Anaconda3\lib\site-packages\altair\utils\schemapi.py in to_dict(self, validate, ignore, context)
#     323             result = _todict(self._args[0], validate=sub_validate, context=context)
#     324         elif not self._args:
# --> 325             result = _todict(
#     326                 {k: v for k, v in self._kwds.items() if k not in ignore},
#     327                 validate=sub_validate,
#
# C:\ProgramData\Anaconda3\lib\site-packages\altair\utils\schemapi.py in _todict(obj, validate, context)
#      58         return [_todict(v, validate, context) for v in obj]
#      59     elif isinstance(obj, dict):
# ---> 60         return {
#      61             k: _todict(v, validate, context)
#      62             for k, v in obj.items()
#
# C:\ProgramData\Anaconda3\lib\site-packages\altair\utils\schemapi.py in <dictcomp>(.0)
#      59     elif isinstance(obj, dict):
#      60         return {
# ---> 61             k: _todict(v, validate, context)
#      62             for k, v in obj.items()
#      63             if v is not Undefined
#
# C:\ProgramData\Anaconda3\lib\site-packages\altair\utils\schemapi.py in _todict(obj, validate, context)
#      56         return obj.to_dict(validate=validate, context=context)
#      57     elif isinstance(obj, (list, tuple, np.ndarray)):
# ---> 58         return [_todict(v, validate, context) for v in obj]
#      59     elif isinstance(obj, dict):
#      60         return {
#
# C:\ProgramData\Anaconda3\lib\site-packages\altair\utils\schemapi.py in <listcomp>(.0)
#      56         return obj.to_dict(validate=validate, context=context)
#      57     elif isinstance(obj, (list, tuple, np.ndarray)):
# ---> 58         return [_todict(v, validate, context) for v in obj]
#      59     elif isinstance(obj, dict):
#      60         return {
#
# C:\ProgramData\Anaconda3\lib\site-packages\altair\utils\schemapi.py in _todict(obj, validate, context)
#      54     """Convert an object to a dict representation."""
#      55     if isinstance(obj, SchemaBase):
# ---> 56         return obj.to_dict(validate=validate, context=context)
#      57     elif isinstance(obj, (list, tuple, np.ndarray)):
#      58         return [_todict(v, validate, context) for v in obj]
#
# C:\ProgramData\Anaconda3\lib\site-packages\altair\vegalite\v4\api.py in to_dict(self, *args, **kwargs)
#     371
#     372         try:
# --> 373             dct = super(TopLevelMixin, copy).to_dict(*args, **kwargs)
#     374         except jsonschema.ValidationError:
#     375             dct = None
#
# C:\ProgramData\Anaconda3\lib\site-packages\altair\utils\schemapi.py in to_dict(self, validate, ignore, context)
#     323             result = _todict(self._args[0], validate=sub_validate, context=context)
#     324         elif not self._args:
# --> 325             result = _todict(
#     326                 {k: v for k, v in self._kwds.items() if k not in ignore},
#     327                 validate=sub_validate,
#
# C:\ProgramData\Anaconda3\lib\site-packages\altair\utils\schemapi.py in _todict(obj, validate, context)
#      58         return [_todict(v, validate, context) for v in obj]
#      59     elif isinstance(obj, dict):
# ---> 60         return {
#      61             k: _todict(v, validate, context)
#      62             for k, v in obj.items()
#
# C:\ProgramData\Anaconda3\lib\site-packages\altair\utils\schemapi.py in <dictcomp>(.0)
#      59     elif isinstance(obj, dict):
#      60         return {
# ---> 61             k: _todict(v, validate, context)
#      62             for k, v in obj.items()
#      63             if v is not Undefined
#
# C:\ProgramData\Anaconda3\lib\site-packages\altair\utils\schemapi.py in _todict(obj, validate, context)
#      54     """Convert an object to a dict representation."""
#      55     if isinstance(obj, SchemaBase):
# ---> 56         return obj.to_dict(validate=validate, context=context)
#      57     elif isinstance(obj, (list, tuple, np.ndarray)):
#      58         return [_todict(v, validate, context) for v in obj]
#
# C:\ProgramData\Anaconda3\lib\site-packages\altair\utils\schemapi.py in to_dict(self, validate, ignore, context)
#     323             result = _todict(self._args[0], validate=sub_validate, context=context)
#     324         elif not self._args:
# --> 325             result = _todict(
#     326                 {k: v for k, v in self._kwds.items() if k not in ignore},
#     327                 validate=sub_validate,
#
# C:\ProgramData\Anaconda3\lib\site-packages\altair\utils\schemapi.py in _todict(obj, validate, context)
#      58         return [_todict(v, validate, context) for v in obj]
#      59     elif isinstance(obj, dict):
# ---> 60         return {
#      61             k: _todict(v, validate, context)
#      62             for k, v in obj.items()
#
# C:\ProgramData\Anaconda3\lib\site-packages\altair\utils\schemapi.py in <dictcomp>(.0)
#      59     elif isinstance(obj, dict):
#      60         return {
# ---> 61             k: _todict(v, validate, context)
#      62             for k, v in obj.items()
#      63             if v is not Undefined
#
# C:\ProgramData\Anaconda3\lib\site-packages\altair\utils\schemapi.py in _todict(obj, validate, context)
#      54     """Convert an object to a dict representation."""
#      55     if isinstance(obj, SchemaBase):
# ---> 56         return obj.to_dict(validate=validate, context=context)
#      57     elif isinstance(obj, (list, tuple, np.ndarray)):
#      58         return [_todict(v, validate, context) for v in obj]
#
# C:\ProgramData\Anaconda3\lib\site-packages\altair\vegalite\v4\schema\channels.py in to_dict(self, validate, ignore, context)
#      38             elif not (type_in_shorthand or type_defined_explicitly):
#      39                 if isinstance(context.get('data', None), pd.DataFrame):
# ---> 40                     raise ValueError("{} encoding field is specified without a type; "
#      41                                      "the type cannot be inferred because it does not "
#      42                                      "match any column in the data.".format(shorthand))
#
# ValueError: EigGruLang encoding field is specified without a type; the type cannot be inferred because it does not match any column in the data.
# alt.LayerChart(...)

# %%
alt.Chart(data2betested).mark_circle(size=60).encode(
    x='KreisLang',
    y='StichtagDatJahr',
    #color='AnzNat',
    #color=alt.Color('AnzNat', scale=alt.Scale(scheme='dark2')),
    color=alt.Color('AnzWhg', scale=alt.Scale(scheme='greens')),
    tooltip=['QuarLang','StichtagDatJahr','AnzWhg']
).interactive() # this makes the axes interactive: now you can zoom & pan
# Out:
# ---------------------------------------------------------------------------
# MaxRowsError                              Traceback (most recent call last)
# C:\ProgramData\Anaconda3\lib\site-packages\altair\vegalite\v4\api.py in to_dict(self, *args, **kwargs)
#     361         copy = self.copy(deep=False)
#     362         original_data = getattr(copy, "data", Undefined)
# --> 363         copy.data = _prepare_data(original_data, context)
#     364
#     365         if original_data is not Undefined:
#
# C:\ProgramData\Anaconda3\lib\site-packages\altair\vegalite\v4\api.py in _prepare_data(data, context)
#      82     # convert dataframes  or objects with __geo_interface__ to dict
#      83     if isinstance(data, pd.DataFrame) or hasattr(data, "__geo_interface__"):
# ---> 84         data = _pipe(data, data_transformers.get())
#      85
#      86     # convert string input to a URLData
#
# C:\ProgramData\Anaconda3\lib\site-packages\toolz\functoolz.py in pipe(data, *funcs)
#     625     """
#     626     for func in funcs:
# --> 627         data = func(data)
#     628     return data
#     629
#
# C:\ProgramData\Anaconda3\lib\site-packages\toolz\functoolz.py in __call__(self, *args, **kwargs)
#     301     def __call__(self, *args, **kwargs):
#     302         try:
# --> 303             return self._partial(*args, **kwargs)
#     304         except TypeError as exc:
#     305             if self._should_curry(args, kwargs, exc):
#
# C:\ProgramData\Anaconda3\lib\site-packages\altair\vegalite\data.py in default_data_transformer(data, max_rows)
#      17 @curried.curry
#      18 def default_data_transformer(data, max_rows=5000):
# ---> 19     return curried.pipe(data, limit_rows(max_rows=max_rows), to_values)
#      20
#      21
#
# C:\ProgramData\Anaconda3\lib\site-packages\toolz\functoolz.py in pipe(data, *funcs)
#     625     """
#     626     for func in funcs:
# --> 627         data = func(data)
#     628     return data
#     629
#
# C:\ProgramData\Anaconda3\lib\site-packages\toolz\functoolz.py in __call__(self, *args, **kwargs)
#     301     def __call__(self, *args, **kwargs):
#     302         try:
# --> 303             return self._partial(*args, **kwargs)
#     304         except TypeError as exc:
#     305             if self._should_curry(args, kwargs, exc):
#
# C:\ProgramData\Anaconda3\lib\site-packages\altair\utils\data.py in limit_rows(data, max_rows)
#      78             return data
#      79     if max_rows is not None and len(values) > max_rows:
# ---> 80         raise MaxRowsError(
#      81             "The number of rows in your dataset is greater "
#      82             "than the maximum allowed ({}). "
#
# MaxRowsError: The number of rows in your dataset is greater than the maximum allowed (5000). For information on how to plot larger datasets in Altair, see the documentation
# alt.Chart(...)

# %% [markdown]
# Test: Choroplethenkarte

# %% [markdown]
# **Test: Choroplethenkarte**
# Importiere die Geodaten als GeoJSON

# %%
# Read abt. Geopandas https://geopandas.org/docs/user_guide/io.html
# Wenn die Daten lokal agelegt sind, dann kannst Du folgendes machen:
##input_stadtquartiere = r"//szh.loc/ssz/data/GIS/Daten/Vektor/_aktuell/stzh.adm_statistische_quartiere_map.json"
##df_stadtquartiere = gpd.read_file(input_stadtquartiere)
##df_stadtquartiere.head(2)
#df_stadtkreise.dtypes

geojson_url = "https://www.ogd.stadt-zuerich.ch/wfs/geoportal/Statistische_Quartiere?service=WFS&version=1.1.0&request=GetFeature&outputFormat=GeoJSON&typename=adm_statistische_quartiere_map"
df_adm_statistische_quartiere_map = gpd.read_file(geojson_url)

df_adm_statistische_quartiere_map.head(5)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-21-2d84af4817d1> in <module>
#       7
#       8 geojson_url = "https://www.ogd.stadt-zuerich.ch/wfs/geoportal/Statistische_Quartiere?service=WFS&version=1.1.0&request=GetFeature&outputFormat=GeoJSON&typename=adm_statistische_quartiere_map"
# ----> 9 df_adm_statistische_quartiere_map = gpd.read_file(geojson_url)
#      10
#      11 df_adm_statistische_quartiere_map.head(5)
#
# NameError: name 'gpd' is not defined

# %% [markdown]
# Joine die importierten statistischen Daten des aktuellen Jahres zum Geodatensatz:
#
# *Siehe dazu Doku zu [Geopandas](https://geopandas.org/docs/user_guide/mergingdata.html)*

# %%
aktuellesJahr.head(2)

# %%
stats_agg_quartiere=aktuellesJahr.groupby(['StichtagDatJahr', 'QuarSort'])['AnzWhg','Wohnungsfl', 'PersInGeb'].sum()
#test = data2betested.groupby(['StichtagDatJahr', 'AlterV20Kurz'])[['AnzBestWir']].agg()
stats_agg_quartiere.head()
#test = data2betested.groupby(['StichtagDatJahr', 'AlterV20Kurz'])[['AnzBestWir']].agg()
# Out:
# <ipython-input-22-3efec1348bab>:1: FutureWarning: Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.
#   stats_agg_quartiere=aktuellesJahr.groupby(['StichtagDatJahr', 'QuarSort'])['AnzWhg','Wohnungsfl', 'PersInGeb'].sum()
#                           AnzWhg  Wohnungsfl  PersInGeb
# StichtagDatJahr QuarSort
# 2020-01-01      1           2317      157636       3317
#                 2            329       28251        675
#                 3            842       62751       1010
#                 4            392       37195        829
#                 5           9951      822501      19756

# %%
# Rename attribute stznr to StatZoneSort, so the IDs have the same name

stadtquartiere_shapes = df_adm_statistische_quartiere_map[['geometry', 'qnr', 'qname', 'knr']].rename(columns={'qnr': 'QuarSort'})

# Merge with `merge` method on shared variable (stznr und StatZoneSort):
stadtquartiere_shapes_joined = stadtquartiere_shapes.merge(stats_agg_quartiere, on='QuarSort')

stadtquartiere_shapes_joined.head(3)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-23-48de2af9fd34> in <module>
#       1 # Rename attribute stznr to StatZoneSort, so the IDs have the same name
#       2
# ----> 3 stadtquartiere_shapes = df_adm_statistische_quartiere_map[['geometry', 'qnr', 'qname', 'knr']].rename(columns={'qnr': 'QuarSort'})
#       4
#       5 # Merge with `merge` method on shared variable (stznr und StatZoneSort):
#
# NameError: name 'df_adm_statistische_quartiere_map' is not defined

# %%
# Plot by StatQuartiere

stadtquartiere_shapes_joined.plot(column='AnzWhg', cmap='viridis', scheme='natural_breaks', legend=True )
#scheme werte: https://matplotlib.org/2.0.2/users/colormaps.html

stadtquartiere_shapes_joined.plot(column='Wohnungsfl', cmap='plasma', scheme='quantiles', legend=True )
#scheme werte: https://matplotlib.org/2.0.2/users/colormaps.html
stadtquartiere_shapes_joined.plot(column='PersInGeb', cmap='cool', scheme='fisherjenks', legend=True )
#scheme werte: https://matplotlib.org/2.0.2/users/colormaps.html

# %% [raw]
# fig, ax = plt.subplots(1, 1)
#
# statzonen_shapes_aktJahr.plot(column='AnzWhg', ax=ax, legend=True, legend_kwds={'label': "Anzahl Personen",'orientation': "horizontal"})

# %% [markdown]
# Noch zu prüfen, folgendes schöne Beispiel: https://docs.bokeh.org/en/latest/docs/user_guide/interaction/legends.html
#
# Konkrete Beispiele von Bookeh in Jupyter NB: https://docs.bokeh.org/en/latest/docs/user_guide/jupyter.html

# %% [markdown]
# **Sharepoint als gecheckt markieren!**

# %% [markdown]
# Record auf Sharepoint: **[Link](http://kollaboration.intranet.stzh.ch/orga/ssz-produkte/Lists/SASA_Outputs/EditForm.aspx?ID=157&Source=%2Forga%2Fssz%2Dprodukte%2FLists%2FSASA%5FOutputs)**
