# %% [markdown]
# # Testing
# ### Median-Einkommen steuerpflichtiger natürlicher Personen nach Jahr, Steuertarif und Stadtkreis.
#
#
# Datum: 03.02.2022

# %% [markdown]
# **Importiere die notwendigen Packages**

# %%
#%pip install geopandas altair fiona requests folium mplleaflet contextily seaborn datetime plotly

# %%
import pandas as pd
import pivottablejs
from pivottablejs import pivot_ui
import numpy as np
import altair as alt
import matplotlib.pyplot as plt
#from datetime import datetime
import datetime
import geopandas as gpd
import folium 
import plotly.express as px
import seaborn as sns

# %% [markdown]
# Definiere Settings. Hier das Zahlenformat von Float-Werten (z.B. *'{:,.2f}'.format* mit Komma als Tausenderzeichen),

# %%
pd.options.display.float_format = '{:.0f}'.format
pd.set_option('display.width', 100)
pd.set_option('display.max_columns', 15)

# %% [markdown]
# Importiere einen Datensatz von der **DWH_INT** Dropzone.
#
# - Beachte dabei die Notation des Pfades...
# - Definiere mal aktuell noch keine weiteren Parameter beim Import

# %% [markdown]
# **Dataset auf INTEG Datenkatalog**: https://data.integ.stadt-zuerich.ch/dataset/int_dwh_fd_median_einkommen_kreis_od1007

# %%
# Filepath
fp = r"//szh.loc/ssz/applikationen/OGD_Dropzone/INT_DWH/fd_median_einkommen_kreis_OD1007/WIR100OD1007.csv"

# Read the data
data2betested = pd.read_csv(
    fp, 
    sep=',',
   parse_dates=['SteuerJahr'],
    #date_parser=lambda x: pd.to_datetime(x, format="%Y"), 
    #index_col="date_time",
    low_memory=False    
    )
print("done")
# Out:
# done

# %% [markdown]
# In der Folge ein paar erste Tests:

# %%
type(data2betested)
# Out:
# pandas.core.frame.DataFrame

# %% [markdown]
#  - 1) Zeige eine kurze Vorschau der importierten Daten
#  - 2) Weise die Datentypen aus
#  - 3) Zeige die Shape (Umfang) des Datensatzes an

# %%
data2betested
# Out:
#     SteuerJahr  KreisSort KreisLang  SteuerTarifSort         SteuerTarifLang  SteuerEinkommen_p50  \
# 0   1999-01-01          1   Kreis 1                0              Grundtarif                   38
# 1   1999-01-01          1   Kreis 1                1      Verheiratetentarif                   83
# 2   1999-01-01          1   Kreis 1                2  Einelternfamilientarif                   47
# 3   1999-01-01          2   Kreis 2                0              Grundtarif                   38
# 4   1999-01-01          2   Kreis 2                1      Verheiratetentarif                   70
# ..         ...        ...       ...              ...                     ...                  ...
# 751 2019-01-01         11  Kreis 11                1      Verheiratetentarif                   76
# 752 2019-01-01         11  Kreis 11                2  Einelternfamilientarif                   43
# ...

# %%
data2betested.dtypes
# Out:
# SteuerJahr             datetime64[ns]
# KreisSort                       int64
# KreisLang                      object
# SteuerTarifSort                 int64
# SteuerTarifLang                object
# SteuerEinkommen_p50           float64
# SteuerEinkommen_p25           float64
# SteuerEinkommen_p75           float64
# dtype: object

# %%
data2betested.shape
# Out:
# (756, 8)

# %% [markdown]
# Beschreibe einzelne Attribute

# %%
data2betested.describe()
# Out:
#        KreisSort  SteuerTarifSort  SteuerEinkommen_p50  SteuerEinkommen_p25  SteuerEinkommen_p75
# count        756              756                  756                  756                  756
# mean           6                1                   56                   32                   88
# std            3                1                   23                   17                   39
# min            1                0                   28                    7                   42
# 25%            4                0                   40                   20                   62
# 50%            6                1                   48                   25                   76
# 75%            9                2                   65                   43                   99
# max           12                2                  136                   85                  226

# %% [markdown]
# Wie viele Nullwerte gibt es im Datensatz?

# %%
data2betested.isnull().sum()
# Out:
# SteuerJahr             0
# KreisSort              0
# KreisLang              0
# SteuerTarifSort        0
# SteuerTarifLang        0
# SteuerEinkommen_p50    0
# SteuerEinkommen_p25    0
# SteuerEinkommen_p75    0
# dtype: int64

# %% [markdown]
# Hier kommen NaN vor, aber nur bei Einelterntarifen:

# %%
check = data2betested.query('SteuerEinkommen_p50.isnull() and SteuerTarifLang == "Einelternfamilientarif"')
check
# Out:
# Empty DataFrame
# Columns: [SteuerJahr, KreisSort, KreisLang, SteuerTarifSort, SteuerTarifLang, SteuerEinkommen_p50, SteuerEinkommen_p25, SteuerEinkommen_p75]
# Index: []

# %% [markdown]
# ### Verwende das Datum als Index
#
# While we did already parse the `datetime` column into the respective datetime type, it currently is just a regular column.
# **To enable quick and convenient queries and aggregations, we need to turn it into the index of the DataFrame**

# %%
data2betested = (
    data2betested
    .copy()
    .assign(
        SteuerJahr_str= lambda x: x.SteuerJahr.astype(str),
    )
    )
data2betested.dtypes
# Out:
# SteuerJahr             datetime64[ns]
# KreisSort                       int64
# KreisLang                      object
# SteuerTarifSort                 int64
# SteuerTarifLang                object
# SteuerEinkommen_p50           float64
# SteuerEinkommen_p25           float64
# SteuerEinkommen_p75           float64
# SteuerJahr_str                 object
# dtype: object

# %%
data2betested = data2betested.set_index("SteuerJahr")

# %%
data2betested.info()
data2betested.index.day.unique()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 756 entries, 1999-01-01 to 2019-01-01
# Data columns (total 8 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   KreisSort            756 non-null    int64
#  1   KreisLang            756 non-null    object
#  2   SteuerTarifSort      756 non-null    int64
#  3   SteuerTarifLang      756 non-null    object
#  4   SteuerEinkommen_p50  756 non-null    float64
#  5   SteuerEinkommen_p25  756 non-null    float64
#  6   SteuerEinkommen_p75  756 non-null    float64
#  7   SteuerJahr_str       756 non-null    object
# dtypes: float64(3), int64(2), object(3)
# memory usage: 53.2+ KB
# Int64Index([1], dtype='int64', name='SteuerJahr')

# %% [markdown]
# Wandle die Spalte Jahr von Int zu **Datetime** um. Dies wird in den meisten Grafiken so benötigt.

# %% [markdown]
# Bereite die Daten für die Grafik unten vor

# %%
Jahre = data2betested.groupby("SteuerJahr")
len(Jahre)
# Out:
# 21

# %% [markdown]
# **Selektionen und Aggregationen**
#
# Check this [Doku](https://www.shanelynn.ie/summarising-aggregation-and-grouping-data-in-python-pandas/)

# %% [markdown]
# **Einfache Visualisierungen zur Plausi**

# %% [markdown]
# Exploriere die Daten mit Pivottable.JS

# %%
from pivottablejs import pivot_ui

pivot_ui(data2betested)
# Out:
#         <iframe
#             width="100%"
#             height="500"
#             src="pivottablejs.html"
#             frameborder="0"
#             allowfullscreen
#         ></iframe>

# %% [markdown]
# Liniendiagramm
# [Link zur Doku](https://altair-viz.github.io/gallery/multiline_highlight.html)

# %%
#data2betested.dtypes

# %%
myGraph = data2betested[['KreisLang','KreisSort','SteuerTarifLang','SteuerEinkommen_p50']].query('KreisSort > 0').loc["2019"].reset_index().sort_values('KreisSort', ascending = False)

# %%
myTitle="Medianeinkommen nach Stadtkreis, 2019"

highlight = alt.selection(type='single', on='mouseover',
                          fields=['SteuerTarifLang'], nearest=True)

base = alt.Chart(myGraph,title=myTitle ).encode(
    x=alt.X('KreisLang', axis=alt.Axis(title='Stadtkreis'))
    ,y=alt.X('SteuerEinkommen_p50', axis=alt.Axis(title='Medianeinkommen p50'))
    , color=alt.Color('SteuerTarifLang', legend=alt.Legend(title="Steuertarif:", orient="right"))  
    ,tooltip=['SteuerJahr', 'KreisLang','SteuerEinkommen_p50', 'SteuerTarifLang']       
)

points = base.mark_circle().encode(
    opacity=alt.value(0)
).add_selection(
    highlight
).properties(
    width=700 , height=300
)
lines = base.mark_line().encode(
    size=alt.condition(~highlight, alt.value(1.5), alt.value(4))
).interactive()

points + lines
# Out:
# alt.LayerChart(...)

# %%
myTitle="Medianeinkommen nach Stadtkreis (alle Tarife)"

#sns.color_palette("flare", as_cmap=True)
myHist = sns.catplot(x="KreisLang"
            , y="SteuerEinkommen_p50"
            , hue="SteuerJahr"
            , kind="violin" #boxen, violin, --> wenn die aggregation nicht genau den werten in der grafik entspricht
            , palette="tab20" #, color="green" 'tab10', 'tab10_r', 'tab20', 'tab20_r', 'tab20b', 'tab20b_r', 'tab20c', 'tab20c_r',
            , height=6
            , aspect=3
            , edgecolor= None
            , order=None, legend_out=True
            ,data=data2betested[['SteuerJahr_str', 'KreisLang','KreisSort','SteuerTarifLang','SteuerEinkommen_p50']]
                     .query('KreisSort > 6 & KreisSort < 13').loc["2015":"2019"]
                     .reset_index().sort_values('KreisLang', ascending = True)
           )
myHist.set_xticklabels(rotation=0)
myHist.set_xlabels('Quartier', fontsize=11) # not set_label
myHist.set_ylabels('Medianeinkommen p50', fontsize=11)

myHist.fig.subplots_adjust(top=0.9) # adjust the Figure in rp
myHist.fig.suptitle(myTitle)
# Out:
# Text(0.5, 0.98, 'Medianeinkommen nach Stadtkreis (alle Tarife)')

# %%
theGrid = data2betested[['SteuerJahr_str', 'KreisLang','KreisSort','SteuerTarifLang','SteuerEinkommen_p50']].query('KreisSort > 0').loc["1999":"2019"].reset_index().sort_values('KreisLang', ascending = True)

# %%
myTitle="Medianeinkommen nach Steuertarif, Stadtkreis und Jahr"

g = sns.FacetGrid(theGrid.reset_index(), col="KreisSort", hue="SteuerTarifLang", col_wrap=4, height=3,)
#g.map(sns.scatterplot, "Jahr", "sum_AnzWhg", alpha=.8)
g.map(sns.lineplot, "SteuerJahr","SteuerEinkommen_p50", alpha=.8)
g.add_legend()
g.fig.subplots_adjust(top=0.9)
g.fig.suptitle(myTitle)
# Out:
# Text(0.5, 0.98, 'Medianeinkommen nach Steuertarif, Stadtkreis und Jahr')

# %%
theGrid = data2betested[['SteuerJahr_str', 'KreisLang','KreisSort','SteuerTarifLang','SteuerEinkommen_p75']].query('KreisSort > 0').loc["1999":"2019"].reset_index().sort_values('KreisLang', ascending = True)

# %%
myTitle="p75-einkommen nach Steuertarif, Stadtkreis und Jahr"

g = sns.FacetGrid(theGrid.reset_index(), col="KreisSort", hue="SteuerTarifLang", col_wrap=4, height=3,)
#g.map(sns.scatterplot, "Jahr", "sum_AnzWhg", alpha=.8)
g.map(sns.lineplot, "SteuerJahr","SteuerEinkommen_p75", alpha=.8)
g.add_legend()
g.fig.subplots_adjust(top=0.9)
g.fig.suptitle(myTitle)
# Out:
# Text(0.5, 0.98, 'p75-einkommen nach Steuertarif, Stadtkreis und Jahr')

# %% [markdown]
# Test: Choroplethenkarte

# %% [markdown]
# #### Test: Choroplethenkarte
#
# Importiere die Geodaten als GeoJSON

# %% [markdown]
# **Stadtquartiere**

# %%
# Read abt. Geopandas https://geopandas.org/docs/user_guide/io.html
# Filepath statzonen
geojson_url = "https://www.ogd.stadt-zuerich.ch/wfs/geoportal/Statistische_Quartiere?service=WFS&version=1.1.0&request=GetFeature&outputFormat=GeoJSON&typename=adm_statistische_quartiere_map"
df_adm_statistische_quartiere_map = gpd.read_file(geojson_url)
df_adm_statistische_quartiere_map.head(1)
# Out:
#                                  id    kname  knr  objectid objid       qname  qnr  \
# 0  adm_statistische_quartiere_map.1  Kreis 7    7         1    34  Hirslanden   73
#
#                                             geometry
# 0  POLYGON ((8.55670 47.36406, 8.55682 47.36410, ...

# %% [markdown]
# **Stadtkreise**

# %%
# Read abt. Geopandas https://geopandas.org/docs/user_guide/io.html
# Filepath statzonen
geojson_url = "https://www.ogd.stadt-zuerich.ch/wfs/geoportal/Stadtkreise?service=WFS&version=1.1.0&request=GetFeature&outputFormat=GeoJSON&typename=adm_stadtkreise_v"
df_adm_stadtkreise_v = gpd.read_file(geojson_url)

df_adm_stadtkreise_v.head(1)
# Out:
#                     id    kname  knr objid                                           geometry
# 0  adm_stadtkreise_v.6  Kreis 7    7     6  POLYGON ((8.54885 47.36602, 8.54901 47.36601, ...

# %%
selectMapAttr1 = data2betested.loc["2019"].query('SteuerTarifLang=="Grundtarif"')
selectMapAttr2 = data2betested.loc["2019"].query('SteuerTarifLang=="Verheiratetentarif"')
selectMapAttr1.head(1)
# Out:
#             KreisSort KreisLang  SteuerTarifSort SteuerTarifLang  SteuerEinkommen_p50  \
# SteuerJahr
# 2019-01-01          1   Kreis 1                0      Grundtarif                   44
#
#             SteuerEinkommen_p25  SteuerEinkommen_p75 SteuerJahr_str
# SteuerJahr
# 2019-01-01                   14                   80     2019-01-01

# %%
# Rename attribute stznr to StatZoneSort, so the IDs have the same name
df_adm_stadtkreise_v_rename = df_adm_stadtkreise_v[['geometry', 'knr', 'kname']].rename(columns={'kname': 'KreisLang'})

# Merge with `merge` method on shared variable (stznr und StatZoneSort):
df_adm_stadtkreise_v_joined = df_adm_stadtkreise_v_rename.merge(selectMapAttr1, on='KreisLang')

df_adm_stadtkreise_v_joined.head(1)
# Out:
#                                             geometry  knr KreisLang  KreisSort  SteuerTarifSort  \
# 0  POLYGON ((8.54885 47.36602, 8.54901 47.36601, ...    7   Kreis 7          7                0
#
#   SteuerTarifLang  SteuerEinkommen_p50  SteuerEinkommen_p25  SteuerEinkommen_p75 SteuerJahr_str
# 0      Grundtarif                   50                   20                   83     2019-01-01

# %% [markdown]
# Joine die importierten statistischen Daten des aktuellen Jahres zum Geodatensatz:
#
# *Siehe dazu Doku zu [Geopandas](https://geopandas.org/docs/user_guide/mergingdata.html)*

# %%
df_adm_stadtkreise_v_joined.plot()
# Out:
# <AxesSubplot:>

# %%
# Plot by StadtKreise

df_adm_stadtkreise_v_joined.plot(column='SteuerEinkommen_p50', cmap='viridis', scheme='natural_breaks', legend=True )
#scheme werte: https://matplotlib.org/2.0.2/users/colormaps.html

df_adm_stadtkreise_v_joined.plot(column='SteuerEinkommen_p50', cmap='plasma', scheme='quantiles', legend=True )
#scheme werte: https://matplotlib.org/2.0.2/users/colormaps.html
df_adm_stadtkreise_v_joined.plot(column='SteuerEinkommen_p75', cmap='cool', scheme='fisherjenks', legend=True )
#scheme werte: https://matplotlib.org/2.0.2/users/colormaps.html

df_adm_stadtkreise_v_joined.plot(column='SteuerEinkommen_p75', cmap='viridis', scheme='natural_breaks', legend=True )
#scheme werte: https://matplotlib.org/2.0.2/users/colormaps.html
# Out:
# <AxesSubplot:>

# %% [markdown]
# ----------------------------------------------------------------------------------------

# %% [markdown]
# #Link https://automating-gis-processes.github.io/site/notebooks/L5/interactive-map-folium.html
#
# # Create a Map instance
# m = folium.Map(location=[60.25, 24.8], tiles = 'cartodbpositron', zoom_start=10, control_scale=True)
#
# # Plot a choropleth map
# # Notice: 'geoid' column that we created earlier needs to be assigned always as the first column
# folium.Choropleth(
#     geo_data=data,
#     name='Population in 2018',
#     data=data,
#     columns=['geoid', 'pop18'],
#     key_on='feature.id',
#     fill_color='YlOrRd',
#     fill_opacity=0.7,
#     line_opacity=0.2,
#     line_color='white',
#     line_weight=0,
#     highlight=False,
#     smooth_factor=1.0,
#     #threshold_scale=[100, 250, 500, 1000, 2000],
#     legend_name= 'Population in Helsinki').add_to(m)
#
# #Show map
# m

# %% [markdown]
# Noch zu prüfen, folgendes schöne Beispiel: https://docs.bokeh.org/en/latest/docs/user_guide/interaction/legends.html
#
# Konkrete Beispiele von Bookeh in Jupyter NB: https://docs.bokeh.org/en/latest/docs/user_guide/jupyter.html
