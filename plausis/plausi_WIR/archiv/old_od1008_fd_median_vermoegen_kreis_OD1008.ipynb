# %% [markdown]
# # Testing
# ### Median-Vermögen steuerpflichtiger natürlicher Personen nach Jahr, Steuertarif und Stadtkreis.
#
#
# Datum: 03.02.2022

# %% [markdown]
# **Importiere die notwendigen Packages**

# %%
#%pip install geopandas altair fiona requests folium mplleaflet contextily seaborn datetime plotly

# %%
import pandas as pd
import pivottablejs
from pivottablejs import pivot_ui
import numpy as np
import altair as alt
import matplotlib.pyplot as plt
#from datetime import datetime
import datetime
import geopandas as gpd
import folium 
import plotly.express as px
import seaborn as sns

# %% [markdown]
# Definiere Settings. Hier das Zahlenformat von Float-Werten (z.B. *'{:,.2f}'.format* mit Komma als Tausenderzeichen),

# %%
pd.options.display.float_format = '{:.0f}'.format
pd.set_option('display.width', 100)
pd.set_option('display.max_columns', 15)

# %% [markdown]
# Importiere einen Datensatz von der **DWH_INT** Dropzone.
#
# - Beachte dabei die Notation des Pfades...
# - Definiere mal aktuell noch keine weiteren Parameter beim Import

# %% [markdown]
# **Dataset auf INTEG Datenkatalog**: https://data.integ.stadt-zuerich.ch/dataset/int_dwh_fd_median_vermoegen_kreis_od1008

# %%
# Filepath
fp = r"//szh.loc/ssz/applikationen/OGD_Dropzone/INT_DWH/fd_median_vermoegen_kreis_OD1008/WIR100OD1008.csv"

# Read the data
data2betested = pd.read_csv(
    fp, 
    sep=',',
   #usecols=[0,1,2,3,4,6],
   #names=['stationid','year','month','avgtemp','latitude','longitude','elevation','station','countryid','country'],
   #skiprows=1,
   parse_dates=['SteuerJahr'],
    #date_parser=lambda x: pd.to_datetime(x, format="%Y"), 
    #index_col="date_time",
    low_memory=False    
    )
print("done")
# Out:
# done

# %% [markdown]
# In der Folge ein paar erste Tests:

# %%
type(data2betested)
# Out:
# pandas.core.frame.DataFrame

# %% [markdown]
#  - 1) Zeige eine kurze Vorschau der importierten Daten
#  - 2) Weise die Datentypen aus
#  - 3) Zeige die Shape (Umfang) des Datensatzes an

# %%
data2betested
# Out:
#     SteuerJahr  KreisSort KreisLang  SteuerTarifSort         SteuerTarifLang  SteuerVermoegen_p50  \
# 0   1999-01-01          1   Kreis 1                0              Grundtarif                   23
# 1   1999-01-01          1   Kreis 1                1      Verheiratetentarif                  182
# 2   1999-01-01          1   Kreis 1                2  Einelternfamilientarif                   28
# 3   1999-01-01          2   Kreis 2                0              Grundtarif                   37
# 4   1999-01-01          2   Kreis 2                1      Verheiratetentarif                  148
# ..         ...        ...       ...              ...                     ...                  ...
# 751 2019-01-01         11  Kreis 11                1      Verheiratetentarif                   97
# 752 2019-01-01         11  Kreis 11                2  Einelternfamilientarif                    7
# 753 2019-01-01         12  Kreis 12                0              Grundtarif                   12
# 754 2019-01-01         12  Kreis 12                1      Verheiratetentarif                   40
# 755 2019-01-01         12  Kreis 12                2  Einelternfamilientarif                    1
#
#      SteuerVermoegen_p25  SteuerVermoegen_p75
# 0                      0                  174
# 1                     22                  711
# 2                      0                  283
# 3                      3                  186
# 4                     33                  458
# ..                   ...                  ...
# 751                    4                  371
# 752                    0                   91
# 753                    0                   76
# 754                    0                  207
# 755                    0                   32
#
# [756 rows x 8 columns]

# %%
data2betested.dtypes
# Out:
# SteuerJahr             datetime64[ns]
# KreisSort                       int64
# KreisLang                      object
# SteuerTarifSort                 int64
# SteuerTarifLang                object
# SteuerVermoegen_p50           float64
# SteuerVermoegen_p25           float64
# SteuerVermoegen_p75           float64
# dtype: object

# %%
data2betested.shape
# Out:
# (756, 8)

# %% [markdown]
# Beschreibe einzelne Attribute

# %%
data2betested.describe()
# Out:
#        KreisSort  SteuerTarifSort  SteuerVermoegen_p50  SteuerVermoegen_p25  SteuerVermoegen_p75
# count        756              756                  756                  756                  756
# mean           6                1                   72                   10                  284
# std            3                1                   97                   23                  314
# min            1                0                    0                    0                   12
# 25%            4                0                   17                    0                   98
# 50%            6                1                   38                    0                  185
# 75%            9                2                   73                    5                  313
# max           12                2                  538                  135                 1734

# %% [markdown]
# Wie viele Nullwerte gibt es im Datensatz?

# %%
data2betested.isnull().sum()
# Out:
# SteuerJahr             0
# KreisSort              0
# KreisLang              0
# SteuerTarifSort        0
# SteuerTarifLang        0
# SteuerVermoegen_p50    0
# SteuerVermoegen_p25    0
# SteuerVermoegen_p75    0
# dtype: int64

# %% [markdown]
# Wandle die Spalte Jahr von Int zu **Datetime** um. Dies wird in den meisten Grafiken so benötigt.

# %%
data2betested['SteuerJahr']=pd.to_datetime(data2betested['SteuerJahr'], format='%Y')

#TO DO --> setze das Datum auf den 31.12. der Jahres.
#test=data2betested[['StichtagDatJahr']].date().replace(month=12, day=31)

data2betested
# Out:
#     SteuerJahr  KreisSort KreisLang  SteuerTarifSort         SteuerTarifLang  SteuerVermoegen_p50  \
# 0   1999-01-01          1   Kreis 1                0              Grundtarif                   23
# 1   1999-01-01          1   Kreis 1                1      Verheiratetentarif                  182
# 2   1999-01-01          1   Kreis 1                2  Einelternfamilientarif                   28
# 3   1999-01-01          2   Kreis 2                0              Grundtarif                   37
# 4   1999-01-01          2   Kreis 2                1      Verheiratetentarif                  148
# ..         ...        ...       ...              ...                     ...                  ...
# 751 2019-01-01         11  Kreis 11                1      Verheiratetentarif                   97
# 752 2019-01-01         11  Kreis 11                2  Einelternfamilientarif                    7
# 753 2019-01-01         12  Kreis 12                0              Grundtarif                   12
# 754 2019-01-01         12  Kreis 12                1      Verheiratetentarif                   40
# 755 2019-01-01         12  Kreis 12                2  Einelternfamilientarif                    1
#
#      SteuerVermoegen_p25  SteuerVermoegen_p75
# 0                      0                  174
# 1                     22                  711
# 2                      0                  283
# 3                      3                  186
# 4                     33                  458
# ..                   ...                  ...
# 751                    4                  371
# 752                    0                   91
# 753                    0                   76
# 754                    0                  207
# 755                    0                   32
#
# [756 rows x 8 columns]

# %% [markdown]
# Bereite die Daten für die Grafik unten vor

# %%
Jahre = data2betested.groupby("SteuerJahr")
len(Jahre)
# Out:
# 21

# %%
for key, group in Jahre:
    print(key, len(group))
# Out:
# 1999-01-01 00:00:00 36
# 2000-01-01 00:00:00 36
# 2001-01-01 00:00:00 36
# 2002-01-01 00:00:00 36
# 2003-01-01 00:00:00 36
# 2004-01-01 00:00:00 36
# 2005-01-01 00:00:00 36
# 2006-01-01 00:00:00 36
# 2007-01-01 00:00:00 36
# 2008-01-01 00:00:00 36
# 2009-01-01 00:00:00 36
# 2010-01-01 00:00:00 36
# 2011-01-01 00:00:00 36
# 2012-01-01 00:00:00 36
# 2013-01-01 00:00:00 36
# 2014-01-01 00:00:00 36
# 2015-01-01 00:00:00 36
# 2016-01-01 00:00:00 36
# 2017-01-01 00:00:00 36
# 2018-01-01 00:00:00 36
# 2019-01-01 00:00:00 36

# %%
myJahr = "2019-01-01"
aktuellesJahr=Jahre.get_group(myJahr)   
aktuellesJahr
# Out:
#     SteuerJahr  KreisSort KreisLang  SteuerTarifSort         SteuerTarifLang  SteuerVermoegen_p50  \
# 720 2019-01-01          1   Kreis 1                0              Grundtarif                   49
# 721 2019-01-01          1   Kreis 1                1      Verheiratetentarif                  427
# 722 2019-01-01          1   Kreis 1                2  Einelternfamilientarif                   65
# 723 2019-01-01          2   Kreis 2                0              Grundtarif                   44
# 724 2019-01-01          2   Kreis 2                1      Verheiratetentarif                  229
# 725 2019-01-01          2   Kreis 2                2  Einelternfamilientarif                   42
# 726 2019-01-01          3   Kreis 3                0              Grundtarif                   32
# 727 2019-01-01          3   Kreis 3                1      Verheiratetentarif                  131
# 728 2019-01-01          3   Kreis 3                2  Einelternfamilientarif                   40
# 729 2019-01-01          4   Kreis 4                0              Grundtarif                   20
# 730 2019-01-01          4   Kreis 4                1      Verheiratetentarif                   60
# 731 2019-01-01          4   Kreis 4                2  Einelternfamilientarif                   23
# 732 2019-01-01          5   Kreis 5                0              Grundtarif                   36
# 733 2019-01-01          5   Kreis 5                1      Verheiratetentarif                  197
# 734 2019-01-01          5   Kreis 5                2  Einelternfamilientarif                   66
# 735 2019-01-01          6   Kreis 6                0              Grundtarif                   52
# 736 2019-01-01          6   Kreis 6                1      Verheiratetentarif                  314
# 737 2019-01-01          6   Kreis 6                2  Einelternfamilientarif                   80
# 738 2019-01-01          7   Kreis 7                0              Grundtarif                   80
# 739 2019-01-01          7   Kreis 7                1      Verheiratetentarif                  531
# 740 2019-01-01          7   Kreis 7                2  Einelternfamilientarif                  123
# 741 2019-01-01          8   Kreis 8                0              Grundtarif                   65
# 742 2019-01-01          8   Kreis 8                1      Verheiratetentarif                  396
# 743 2019-01-01          8   Kreis 8                2  Einelternfamilientarif                  104
# 744 2019-01-01          9   Kreis 9                0              Grundtarif                   27
# 745 2019-01-01          9   Kreis 9                1      Verheiratetentarif                  106
# 746 2019-01-01          9   Kreis 9                2  Einelternfamilientarif                   20
# 747 2019-01-01         10  Kreis 10                0              Grundtarif                   49
# 748 2019-01-01         10  Kreis 10                1      Verheiratetentarif                  249
# 749 2019-01-01         10  Kreis 10                2  Einelternfamilientarif                   56
# 750 2019-01-01         11  Kreis 11                0              Grundtarif                   23
# 751 2019-01-01         11  Kreis 11                1      Verheiratetentarif                   97
# 752 2019-01-01         11  Kreis 11                2  Einelternfamilientarif                    7
# 753 2019-01-01         12  Kreis 12                0              Grundtarif                   12
# 754 2019-01-01         12  Kreis 12                1      Verheiratetentarif                   40
# 755 2019-01-01         12  Kreis 12                2  Einelternfamilientarif                    1
#
#      SteuerVermoegen_p25  SteuerVermoegen_p75
# 720                    2                  293
# 721                   83                 1512
# 722                    0                  436
# 723                    4                  232
# 724                   44                  724
# 725                    1                  185
# 726                    2                  147
# 727                   13                  447
# 728                    0                  154
# 729                    0                  101
# 730                    0                  270
# 731                    0                  129
# 732                    1                  158
# 733                   26                  574
# 734                    6                  231
# 735                    5                  224
# 736                   69                  892
# 737                    9                  269
# 738                    9                  421
# 739                  135                 1705
# 740                   16                  460
# 741                    6                  310
# 742                   97                 1216
# 743                    8                  430
# 744                    0                  133
# 745                    7                  374
# 746                    0                  119
# 747                    5                  217
# 748                   58                  737
# 749                    3                  239
# 750                    0                  127
# 751                    4                  371
# 752                    0                   91
# 753                    0                   76
# 754                    0                  207
# 755                    0                   32

# %% [markdown]
# **Selektionen und Aggregationen**
#
# Check this [Doku](https://www.shanelynn.ie/summarising-aggregation-and-grouping-data-in-python-pandas/)

# %% [markdown]
# **Einfache Visualisierungen zur Plausi**

# %% [markdown]
# Exploriere die Daten mit Pivottable.JS

# %%
from pivottablejs import pivot_ui

pivot_ui(data2betested)
# Out:
#         <iframe
#             width="100%"
#             height="500"
#             src="pivottablejs.html"
#             frameborder="0"
#             allowfullscreen
#         ></iframe>

# %% [markdown]
# Liniendiagramm
# [Link zur Doku](https://altair-viz.github.io/gallery/multiline_highlight.html)

# %%
myGraph = data2betested[(data2betested.KreisSort >1) & (data2betested.SteuerJahr == "2019")]
myGraph.head()
# Out:
#     SteuerJahr  KreisSort KreisLang  SteuerTarifSort         SteuerTarifLang  SteuerVermoegen_p50  \
# 723 2019-01-01          2   Kreis 2                0              Grundtarif                   44
# 724 2019-01-01          2   Kreis 2                1      Verheiratetentarif                  229
# 725 2019-01-01          2   Kreis 2                2  Einelternfamilientarif                   42
# 726 2019-01-01          3   Kreis 3                0              Grundtarif                   32
# 727 2019-01-01          3   Kreis 3                1      Verheiratetentarif                  131
#
#      SteuerVermoegen_p25  SteuerVermoegen_p75
# 723                    4                  232
# 724                   44                  724
# 725                    1                  185
# 726                    2                  147
# 727                   13                  447

# %%
myTitle="Medianvermögen nach Stadtquartier, 2019"

highlight = alt.selection(type='single', on='mouseover',
                          fields=['SteuerTarifLang'], nearest=True)

base = alt.Chart(myGraph,title=myTitle ).encode(
    x=alt.X('KreisLang', axis=alt.Axis(title='Stadtkreis'))
    ,y=alt.X('SteuerVermoegen_p50', axis=alt.Axis(title='Medianvermögen p50'))
    , color=alt.Color('SteuerTarifLang', legend=alt.Legend(title="Steuertarif:", orient="right"))  
    ,tooltip=['SteuerJahr', 'KreisLang','SteuerVermoegen_p50', 'SteuerTarifLang']       
)

points = base.mark_circle().encode(
    opacity=alt.value(0)
).add_selection(
    highlight
).properties(
    width=700 , height=300
)
lines = base.mark_line().encode(
    size=alt.condition(~highlight, alt.value(1.5), alt.value(4))
).interactive()

points + lines
# Out:
# alt.LayerChart(...)

# %%
alt.Chart(myGraph).mark_circle(size=60).encode(
    x='KreisLang',
    y='SteuerVermoegen_p50',
    color='SteuerTarifLang',
    tooltip=['SteuerJahr','SteuerTarifLang', 'KreisLang','SteuerVermoegen_p25', 'SteuerVermoegen_p50','SteuerVermoegen_p75']
).interactive() # this makes the axes interactive: now you can zoom & pan
# Out:
# alt.Chart(...)

# %%
import seaborn as sns
sns.set(style="darkgrid")
sns.histplot(data=myGraph, x="SteuerVermoegen_p50") #, y="KonOGDKurz")
plt.show();

# %% [markdown]
# Test: Choroplethenkarte

# %% [markdown]
# ### Choroplethenkarte
# Importiere die Geodaten als GeoJSON
#
# **Stadtkreise:**

# %%
# Read abt. Geopandas https://geopandas.org/docs/user_guide/io.html
# Filepath statzonen
geojson_url = "https://www.ogd.stadt-zuerich.ch/wfs/geoportal/Stadtkreise?service=WFS&version=1.1.0&request=GetFeature&outputFormat=GeoJSON&typename=adm_stadtkreise_v"
df_adm_stadtkreise_v = gpd.read_file(geojson_url)

df_adm_stadtkreise_v.head(5)
# Out:
#                      id     kname  knr objid                                           geometry
# 0   adm_stadtkreise_v.6   Kreis 7    7     6  POLYGON ((8.54885 47.36602, 8.54901 47.36601, ...
# 1  adm_stadtkreise_v.10  Kreis 11   11    10  POLYGON ((8.55562 47.40129, 8.55543 47.40137, ...
# 2   adm_stadtkreise_v.4   Kreis 9    9     4  POLYGON ((8.50320 47.38100, 8.50308 47.38131, ...
# 3   adm_stadtkreise_v.8   Kreis 2    2     8  POLYGON ((8.52820 47.36885, 8.52901 47.36938, ...
# 4  adm_stadtkreise_v.12  Kreis 10   10    12  POLYGON ((8.50543 47.39495, 8.50532 47.39497, ...

# %% [markdown]
# Joine die importierten statistischen Daten des aktuellen Jahres zum Geodatensatz:
#
# *Siehe dazu Doku zu [Geopandas](https://geopandas.org/docs/user_guide/mergingdata.html)*

# %%
selectMapAttr1 = data2betested[(data2betested.SteuerTarifLang=="Grundtarif") & (data2betested.SteuerJahr == "2018")]
selectMapAttr2 = data2betested[(data2betested.SteuerTarifLang=="Verheiratetentarif") & (data2betested.SteuerJahr == "2018")]

# %%
selectMapAttr1.head(3)
#selectMapAttr1.info()
# Out:
#     SteuerJahr  KreisSort KreisLang  SteuerTarifSort SteuerTarifLang  SteuerVermoegen_p50  \
# 684 2018-01-01          1   Kreis 1                0      Grundtarif                   48
# 687 2018-01-01          2   Kreis 2                0      Grundtarif                   46
# 690 2018-01-01          3   Kreis 3                0      Grundtarif                   33
#
#      SteuerVermoegen_p25  SteuerVermoegen_p75
# 684                    3                  296
# 687                    4                  225
# 690                    2                  145

# %%
# Rename attribute stznr to StatZoneSort, so the IDs have the same name

df_adm_stadtkreise_v_rename = df_adm_stadtkreise_v[['geometry', 'knr', 'kname']].rename(columns={'kname': 'KreisLang'})

# Merge with `merge` method on shared variable (stznr und StatZoneSort):
df_adm_stadtkreise_v_joined = df_adm_stadtkreise_v_rename.merge(selectMapAttr1, on='KreisLang')

print('done')
# Out:
# done

# %%
df_adm_stadtkreise_v_joined.plot()
# Out:
# <AxesSubplot:>

# %%
# Plot by StadtKreise

df_adm_stadtkreise_v_joined.plot(column='SteuerVermoegen_p50', cmap='viridis', scheme='natural_breaks', legend=True )
#scheme werte: https://matplotlib.org/2.0.2/users/colormaps.html

df_adm_stadtkreise_v_joined.plot(column='SteuerVermoegen_p50', cmap='plasma', scheme='quantiles', legend=True )
#scheme werte: https://matplotlib.org/2.0.2/users/colormaps.html
df_adm_stadtkreise_v_joined.plot(column='SteuerVermoegen_p50', cmap='cool', scheme='fisherjenks', legend=True )
#scheme werte: https://matplotlib.org/2.0.2/users/colormaps.html

df_adm_stadtkreise_v_joined.plot(column='SteuerVermoegen_p50', cmap='viridis', scheme='natural_breaks', legend=True )
#scheme werte: https://matplotlib.org/2.0.2/users/colormaps.html
# Out:
# <AxesSubplot:>

# %% [markdown]
# ----------------------------------------------------------------------------------------

# %% [markdown]
# #Link https://automating-gis-processes.github.io/site/notebooks/L5/interactive-map-folium.html
#
# # Create a Map instance
# m = folium.Map(location=[60.25, 24.8], tiles = 'cartodbpositron', zoom_start=10, control_scale=True)
#
# # Plot a choropleth map
# # Notice: 'geoid' column that we created earlier needs to be assigned always as the first column
# folium.Choropleth(
#     geo_data=data,
#     name='Population in 2018',
#     data=data,
#     columns=['geoid', 'pop18'],
#     key_on='feature.id',
#     fill_color='YlOrRd',
#     fill_opacity=0.7,
#     line_opacity=0.2,
#     line_color='white',
#     line_weight=0,
#     highlight=False,
#     smooth_factor=1.0,
#     #threshold_scale=[100, 250, 500, 1000, 2000],
#     legend_name= 'Population in Helsinki').add_to(m)
#
# #Show map
# m

# %% [markdown]
# Noch zu prüfen, folgendes schöne Beispiel: https://docs.bokeh.org/en/latest/docs/user_guide/interaction/legends.html
#
# Konkrete Beispiele von Bookeh in Jupyter NB: https://docs.bokeh.org/en/latest/docs/user_guide/jupyter.html
